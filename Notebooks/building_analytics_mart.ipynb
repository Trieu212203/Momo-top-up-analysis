# %% [markdown]
# # 📊 Building Analytics Mart
#
# This notebook processes the integrated dataset to create various analytics focus areas (Marts).

# %% [markdown]
# ## 1. Setup & Initialization
#
# Importing libraries and defining paths to the processed transaction data.

# %%
import pandas as pd

# %%
path = "C://Users//ASUS//Documents//Project//Momo case study//Data//processed//final.csv"

# %%
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13495 entries, 0 to 13494
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          13495 non-null  int64
#  1   order_id         13495 non-null  int64
#  2   Date             13495 non-null  object
#  3   Amount           13495 non-null  float64
#  4   Merchant_id      13495 non-null  int64
#  5   Purchase_status  13495 non-null  int64
#  6   Merchant_name    13495 non-null  object
#  7   Rate_pct         13495 non-null  int64
#  8   Revenue          13495 non-null  float64
#  9   First_tran_date  13495 non-null  object
#  10  Location         13495 non-null  object
#  11  Age              13495 non-null  object
#  12  Gender           13495 non-null  object
#  13  Type_user        13495 non-null  object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# ## 2. Data Type Optimization
#
# Ensuring all date columns are in datetime format and optimizing categorical columns to reduce memory footprint.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['First_tran_date'] = pd.to_datetime(df['First_tran_date'])

# %%
cat_cols = [
    'Merchant_name',
    'Location',
    'Age',
    'Gender',
    'Type_user'
]

for col in cat_cols:
    df[col] = df[col].astype('category')

# %%
df['Purchase_status'] = df['Purchase_status'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13495 entries, 0 to 13494
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          13495 non-null  int64
#  1   order_id         13495 non-null  int64
#  2   Date             13495 non-null  datetime64[ns]
#  3   Amount           13495 non-null  float64
#  4   Merchant_id      13495 non-null  int64
#  5   Purchase_status  13495 non-null  int8
#  6   Merchant_name    13495 non-null  category
#  7   Rate_pct         13495 non-null  int64
#  8   Revenue          13495 non-null  float64
#  9   First_tran_date  13495 non-null  datetime64[ns]
#  10  Location         13495 non-null  category
#  11  Age              13495 non-null  category
#  12  Gender           13495 non-null  category
#  13  Type_user        13495 non-null  category
# dtypes: category(5), datetime64[ns](2), float64(2), int64(4), int8(1)
# memory usage: 923.4 KB

# %% [markdown]
# ## 3. Time Feature Extraction
#
# Extracting month and year for periodic analysis.

# %%
df['month'] = df['Date'].dt.to_period('M').astype(str)
df['year'] = df['Date'].dt.year

# %% [markdown]
# ## 4. Growth Analytics Mart
#
# Calculating active users, new users, and current users per month to track platform growth.

# %%
mart_growth = (
    df.groupby('month')
      .agg(
          active_users = ('user_id','nunique'),
          new_users = ('user_id',
                       lambda x: x[df.loc[x.index,'Type_user']=='New'].nunique())
      )
      .reset_index()
)

mart_growth['current_users'] = (
    mart_growth['active_users'] - mart_growth['new_users']
)

mart_growth['pct_new_users'] = (
    mart_growth['new_users'] / mart_growth['active_users'])

# %%
mart_growth
# Out:
#       month  active_users  new_users  current_users  pct_new_users
# 0   2020-01          1000         85            915       0.085000
# 1   2020-02           969         91            878       0.093911
# 2   2020-03          1098        113            985       0.102914
# 3   2020-04          1027         81            946       0.078870
# 4   2020-05          1104         72           1032       0.065217
# 5   2020-06          1116         62           1054       0.055556
# 6   2020-07          1149         72           1077       0.062663
# 7   2020-08          1153         84           1069       0.072853
# 8   2020-09          1189         82           1107       0.068966
# 9   2020-10          1209         79           1130       0.065343
# 10  2020-11          1214         90           1124       0.074135
# 11  2020-12          1234         76           1158       0.061588

# %% [markdown]
# ## 5. Revenue Analytics Mart
#
# Analyzing financial metrics including Average Order Value (AOV), Revenue per User, and Take Rate.

# %%
mart_revenue = (
    df.groupby('month')
    .agg(
        total_txn = ('order_id','count'),
          total_amount = ('Amount','sum'),
          revenue = ('Revenue','sum'),
          active_users = ('user_id','nunique')
      )
      .reset_index()
)

mart_revenue['AOV'] = mart_revenue['total_amount'] / mart_revenue['total_txn']
mart_revenue['revenue_per_user'] = mart_revenue['revenue'] / mart_revenue['active_users']
mart_revenue['take_rate'] = mart_revenue['revenue'] / mart_revenue['total_amount']

# %%
mart_revenue
# Out:
#       month  total_txn  total_amount     revenue  active_users           AOV  \
# 0   2020-01       1000    53814234.0  1409827.02          1000  53814.234000
# 1   2020-02        972    52680000.0  1378500.00           969  54197.530864
# 2   2020-03       1098    58200000.0  1584000.00          1098  53005.464481
# 3   2020-04       1027    54150000.0  1488300.00          1027  52726.387537
# 4   2020-05       1104    52950000.0  1463700.00          1104  47961.956522
# 5   2020-06       1118    58250000.0  1617200.00          1116  52101.967800
# 6   2020-07       1153    58940000.0  1581900.00          1149  51118.820468
# 7   2020-08       1153    59950000.0  1618700.00          1153  51994.796184
# 8   2020-09       1189    63400000.0  1702200.00          1189  53322.119428
# 9   2020-10       1211    61690000.0  1690900.00          1209  50941.370768
# 10  2020-11       1215    59270000.0  1539300.00          1214  48781.893004
# 11  2020-12       1255    61310000.0  1638200.00          1234  48852.589641
#
#     revenue_per_user  take_rate
# 0        1409.827020   0.026198
# 1        1422.600619   0.026167
# 2        1442.622951   0.027216
# 3        1449.172347   0.027485
# 4        1325.815217   0.027643
# 5        1449.103943   0.027763
# 6        1376.762402   0.026839
# 7        1403.902862   0.027001
# 8        1431.623213   0.026849
# 9        1398.593879   0.027410
# 10       1267.957166   0.025971
# 11       1327.552674   0.026720

# %% [markdown]
# ## 6. Merchant Performance Mart
#
# Aggregating users and revenue by merchant to identify top-performing partners.

# %%
mart_merchant = (
    df.groupby(['month','Merchant_name'])
      .agg(
          users = ('user_id','nunique'),
          txn = ('order_id','count'),
          amount = ('Amount','sum'),
          revenue = ('Revenue','sum')
      )
      .reset_index()
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18208\1533046893.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['month','Merchant_name'])

# %% [markdown]
# ## 7. User Behavior Mart
#
# Segmenting data by demographics (Location, Gender, Age) and user type to understand behavior patterns.

# %%
mart_behavior = (
    df.groupby(['month','Type_user','Location','Gender','Age'])
      .agg(
          users = ('user_id','nunique'),
          txn = ('order_id','count'),
          revenue = ('Revenue','sum')
      )
      .reset_index()
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18208\304108706.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['month','Type_user','Location','Gender','Age'])

# %% [markdown]
# ## 8. Cohort Analysis Mart
#
# Tracking user retention by comparing the month of their first transaction with subsequent activity months.

# %%
df['first_month'] = df['First_tran_date'].dt.to_period('M').astype(str)

mart_cohort = (
    df.groupby(['first_month','month'])
      .agg(users=('user_id','nunique'))
      .reset_index()
)

# %% [markdown]
# ## 9. Data Persistence
#
# Creating the mart directory and exporting all processed analytics marts to CSV files for visualization.

# %%
import os

output_dir = "C://Users//ASUS//Documents//Project//Momo case study//Data//processed//mart"
os.makedirs(output_dir, exist_ok=True)

# %%
mart_behavior.to_csv(f"{output_dir}/mart_behavior.csv", encoding = 'utf-8-sig', index = False)
mart_revenue.to_csv(f"{output_dir}/mart_revenue.csv", encoding = 'utf-8-sig', index = False)
mart_growth.to_csv(f"{output_dir}/mart_growth.csv", encoding = 'utf-8-sig', index = False)
mart_cohort.to_csv(f"{output_dir}/mart_cohort.csv", encoding = 'utf-8-sig', index = False)
mart_merchant.to_csv(f"{output_dir}/mart_merchant.csv", encoding = 'utf-8-sig', index = False)
