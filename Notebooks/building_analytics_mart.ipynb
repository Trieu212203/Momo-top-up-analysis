# %%
import pandas as pd

# %%
df = pd.read_csv('final.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13495 entries, 0 to 13494
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          13495 non-null  int64
#  1   order_id         13495 non-null  int64
#  2   Date             13495 non-null  object
#  3   Amount           13495 non-null  float64
#  4   Merchant_id      13495 non-null  int64
#  5   Purchase_status  13495 non-null  int64
#  6   Merchant_name    13495 non-null  object
#  7   Rate_pct         13495 non-null  int64
#  8   Revenue          13495 non-null  float64
#  9   First_tran_date  13495 non-null  object
#  10  Location         13495 non-null  object
#  11  Age              13495 non-null  object
#  12  Gender           13495 non-null  object
#  13  Type_user        13495 non-null  object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.4+ MB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['First_tran_date'] = pd.to_datetime(df['First_tran_date'])

# %%
cat_cols = [
    'Merchant_name',
    'Location',
    'Age',
    'Gender',
    'Type_user'
]

for col in cat_cols:
    df[col] = df[col].astype('category')

# %%
df['Purchase_status'] = df['Purchase_status'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13495 entries, 0 to 13494
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          13495 non-null  int64
#  1   order_id         13495 non-null  int64
#  2   Date             13495 non-null  datetime64[ns]
#  3   Amount           13495 non-null  float64
#  4   Merchant_id      13495 non-null  int64
#  5   Purchase_status  13495 non-null  int8
#  6   Merchant_name    13495 non-null  category
#  7   Rate_pct         13495 non-null  int64
#  8   Revenue          13495 non-null  float64
#  9   First_tran_date  13495 non-null  datetime64[ns]
#  10  Location         13495 non-null  category
#  11  Age              13495 non-null  category
#  12  Gender           13495 non-null  category
#  13  Type_user        13495 non-null  category
# dtypes: category(5), datetime64[ns](2), float64(2), int64(4), int8(1)
# memory usage: 923.4 KB

# %%
df['month'] = df['Date'].dt.to_period('M').astype(str)
df['year'] = df['Date'].dt.year

# %%
mart_growth = (
    df.groupby('month')
      .agg(
          active_users = ('user_id','nunique'),
          new_users = ('user_id',
                       lambda x: x[df.loc[x.index,'Type_user']=='New'].nunique())
      )
      .reset_index()
)

mart_growth['current_users'] = (
    mart_growth['active_users'] - mart_growth['new_users']
)

mart_growth['pct_new_users'] = (
    mart_growth['new_users'] / mart_growth['active_users'])

# %%
mart_growth
# Out:
#       month  active_users  new_users  current_users  pct_new_users
# 0   2020-01          1000         85            915       0.085000
# 1   2020-02           969         91            878       0.093911
# 2   2020-03          1098        113            985       0.102914
# 3   2020-04          1027         81            946       0.078870
# 4   2020-05          1104         72           1032       0.065217
# 5   2020-06          1116         62           1054       0.055556
# 6   2020-07          1149         72           1077       0.062663
# 7   2020-08          1153         84           1069       0.072853
# 8   2020-09          1189         82           1107       0.068966
# 9   2020-10          1209         79           1130       0.065343
# 10  2020-11          1214         90           1124       0.074135
# 11  2020-12          1234         76           1158       0.061588

# %%
mart_revenue = (
    df.groupby('month')
    .agg(
        total_txn = ('order_id','count'),
          total_amount = ('Amount','sum'),
          revenue = ('Revenue','sum'),
          active_users = ('user_id','nunique')
      )
      .reset_index()
)

mart_revenue['AOV'] = mart_revenue['total_amount'] / mart_revenue['total_txn']
mart_revenue['revenue_per_user'] = mart_revenue['revenue'] / mart_revenue['active_users']
mart_revenue['take_rate'] = mart_revenue['revenue'] / mart_revenue['total_amount']

# %%
mart_revenue
# Out:
#       month  total_txn  total_amount      revenue  active_users           AOV  \
# 0   2020-01       1000    53814234.0  140982702.0          1000  53814.234000
# 1   2020-02        972    52680000.0  137850000.0           969  54197.530864
# 2   2020-03       1098    58200000.0  158400000.0          1098  53005.464481
# 3   2020-04       1027    54150000.0  148830000.0          1027  52726.387537
# 4   2020-05       1104    52950000.0  146370000.0          1104  47961.956522
# 5   2020-06       1118    58250000.0  161720000.0          1116  52101.967800
# 6   2020-07       1153    58940000.0  158190000.0          1149  51118.820468
# 7   2020-08       1153    59950000.0  161870000.0          1153  51994.796184
# 8   2020-09       1189    63400000.0  170220000.0          1189  53322.119428
# 9   2020-10       1211    61690000.0  169090000.0          1209  50941.370768
# 10  2020-11       1215    59270000.0  153930000.0          1214  48781.893004
# 11  2020-12       1255    61310000.0  163820000.0          1234  48852.589641
#
#     revenue_per_user  take_rate
# 0      140982.702000   2.619803
# 1      142260.061920   2.616743
# 2      144262.295082   2.721649
# 3      144917.234664   2.748476
# 4      132581.521739   2.764306
# 5      144910.394265   2.776309
# 6      137676.240209   2.683916
# 7      140390.286210   2.700083
# 8      143162.321278   2.684858
# 9      139859.387924   2.740963
# 10     126795.716639   2.597098
# 11     132755.267423   2.671995

# %%
mart_merchant = (
    df.groupby(['month','Merchant_name'])
      .agg(
          users = ('user_id','nunique'),
          txn = ('order_id','count'),
          amount = ('Amount','sum'),
          revenue = ('Revenue','sum')
      )
      .reset_index()
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14364\1533046893.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['month','Merchant_name'])

# %%
mart_behavior = (
    df.groupby(['month','Type_user','Location','Age','Gender'])
      .agg(
          users = ('user_id','nunique'),
          txn = ('order_id','count'),
          revenue = ('Revenue','sum')
      )
      .reset_index()
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14364\234216721.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['month','Type_user','Location','Age','Gender'])

# %%
df['first_month'] = df['First_tran_date'].dt.to_period('M').astype(str)

mart_cohort = (
    df.groupby(['first_month','month'])
      .agg(users=('user_id','nunique'))
      .reset_index()
)

# %%
mart_merchant
# Out:
#       month Merchant_name  users  txn      amount     revenue
# 0   2020-01       Gmobile      0    0         0.0         0.0
# 1   2020-01      Mobifone    282  282  15214234.0  45642702.0
# 2   2020-01  Vietnamobile     42   42   1140000.0   4560000.0
# 3   2020-01       Viettel    513  513  29530000.0  59060000.0
# 48  2020-10       Viettel    622  622  29870000.0  59740000.0
# 49  2020-10     Vinaphone    223  223  12120000.0  48480000.0
# 50  2020-11       Gmobile      0    0         0.0         0.0
# 51  2020-11      Mobifone    352  352  15310000.0  45930000.0
# 52  2020-11  Vietnamobile     56   56   2160000.0   8640000.0
# 53  2020-11       Viettel    625  626  33920000.0  67840000.0
# 54  2020-11     Vinaphone    181  181   7880000.0  31520000.0
# 55  2020-12       Gmobile      0    0         0.0         0.0
# 56  2020-12      Mobifone    362  369  17240000.0  51720000.0
# 57  2020-12  Vietnamobile     70   70   3230000.0  12920000.0
# 58  2020-12       Viettel    623  624  32090000.0  64180000.0
# 59  2020-12     Vinaphone    191  192   8750000.0  35000000.0

# %%
mart_behavior
# Out:
#        month Type_user      Location       Age  Gender  users  txn    revenue
# 0    2020-01   Current          HCMC  18_to_22  FEMALE     18   18  1040000.0
# 1    2020-01   Current          HCMC  18_to_22    MALE     17   17  1460000.0
# 2    2020-01   Current          HCMC  23_to_27  FEMALE     43   43  5850000.0
# 3    2020-01   Current          HCMC  23_to_27    MALE     50   50  5620000.0
# 4    2020-01   Current          HCMC  28_to_32  FEMALE     36   36  4570000.0
# ..       ...       ...           ...       ...     ...    ...  ...        ...
# 859  2020-12       New  Other Cities  33_to_37    MALE      1    1   400000.0
# 860  2020-12       New  Other Cities       >37  FEMALE      4    4   140000.0
# 861  2020-12       New  Other Cities       >37    MALE      3    3   120000.0
# 862  2020-12       New  Other Cities   unknown  FEMALE     18   18  2380000.0
# 863  2020-12       New  Other Cities   unknown    MALE     25   25  1870000.0
#
# [864 rows x 8 columns]

# %%
mart_cohort
# Out:
#     first_month    month  users
# 0       2016-01  2020-01      2
# 1       2016-01  2020-02      4
# 2       2016-01  2020-03      3
# 3       2016-01  2020-05      2
# 4       2016-01  2020-07      4
# ..          ...      ...    ...
# 612     2020-10  2020-11     65
# 613     2020-10  2020-12     63
# 614     2020-11  2020-11     90
# 615     2020-11  2020-12     68
# 616     2020-12  2020-12     76
#
# [617 rows x 3 columns]

# %%
import os

output_dir = "C://Users//ASUS//Documents//Project//Momo case study//Data//processed//mart"
os.makedirs(output_dir, exist_ok=True)

# %%
mart_behavior.to_csv(f"{output_dir}/mart_behavior.csv", encoding = 'utf-8-sig', index = False)
mart_revenue.to_csv(f"{output_dir}/mart_revenue.csv", encoding = 'utf-8-sig', index = False)
mart_growth.to_csv(f"{output_dir}/mart_growth.csv", encoding = 'utf-8-sig', index = False)
mart_cohort.to_csv(f"{output_dir}/mart_cohort.csv", encoding = 'utf-8-sig', index = False)
mart_merchant.to_csv(f"{output_dir}/mart_merchant.csv", encoding = 'utf-8-sig', index = False)
